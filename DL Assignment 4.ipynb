# %%
# 1) Import libraries
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf 
import seaborn as sns
from tensorflow.keras.models import Model
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from keras import Sequential
sns.set()
import numpy as np

from tensorflow.keras import layers, losses

# %%
# 2) Upload dataset
dataframe = pd.read_csv('http://storage.googleapis.com/download.tensorflow.org/data/ecg.csv', header=None)
raw_data = dataframe.values
dataframe.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0 -0.112522 -2.827204 -3.773897 -4.349751 -4.376041 -3.474986 -2.181408
# 1 -1.100878 -3.996840 -4.285843 -4.506579 -4.022377 -3.234368 -1.566126
# 2 -0.567088 -2.593450 -3.874230 -4.584095 -4.187449 -3.151462 -1.742940
# 3  0.490473 -1.914407 -3.616364 -4.318823 -4.268016 -3.881110 -2.993280
# 4  0.800232 -0.874252 -2.384761 -3.973292 -4.338224 -3.802422 -2.534510
#
#         7         8         9    ...       131       132       133       134  \
# 0 -1.818286 -1.250522 -0.477492  ...  0.792168  0.933541  0.796958  0.578621
# 1 -0.992258 -0.754680  0.042321  ...  0.538356  0.656881  0.787490  0.724046
# 2 -1.490659 -1.183580 -0.394229  ...  0.886073  0.531452  0.311377 -0.021919
# 3 -1.671131 -1.333884 -0.965629  ...  0.350816  0.499111  0.600345  0.842069
# 4 -1.783423 -1.594450 -0.753199  ...  1.148884  0.958434  1.059025  1.371682
#
#         135       136       137       138       139  140
# 0  0.257740  0.228077  0.123431  0.925286  0.193137  1.0
# 1  0.555784  0.476333  0.773820  1.119621 -1.436250  1.0
# 2 -0.713683 -0.532197  0.321097  0.904227 -0.421797  1.0
# 3  0.952074  0.990133  1.086798  1.403011 -0.383564  1.0
# 4  1.277392  0.960304  0.971020  1.614392  1.421456  1.0
#
# [5 rows x 141 columns]

# %%
# Normalize the data
labels = raw_data[:, -1]
data = raw_data[:, 0:-1]

# %%
pd.Series(labels).value_counts()
# Out:
# 1.0    2919
# 0.0    2079
# dtype: int64

# %%
train_data, test_data, train_labels, test_labels = train_test_split(
    data, labels, test_size=0.2, random_state=21
)

# %%
min = np.min(train_data)
max = np.max(train_data)

train_data = (train_data - min) / (max - min)
test_data = (test_data - min) / (max - min)

# %%
train_labels = train_labels.astype(bool)
test_labels = test_labels.astype(bool)

normal_train_data = train_data[train_labels]
normal_test_data = test_data[test_labels]

anomalous_train_data = train_data[~train_labels]
anomalous_test_data = test_data[~test_labels]

# %%
~train_labels
# Out:
# array([False, False, False, ..., False, False, False])

# %%
plt.grid()
plt.plot(np.arange(140), normal_train_data[0])
plt.title("A Normal ECG")
plt.show()

# %%
plt.grid()
plt.plot(np.arange(140), anomalous_train_data[0])
plt.title("An Anomalous ECG")
plt.show()

# %%
# encode  convert it into latent representation
class AnomalyDetector(Model):
  def __init__(self):
    super(AnomalyDetector, self).__init__()
    self.encoder = tf.keras.Sequential([
      layers.Dense(32, activation="relu"),
      layers.Dense(16, activation="relu"),
      layers.Dense(8, activation="relu")])

    self.decoder = tf.keras.Sequential([
      layers.Dense(16, activation="relu"),
      layers.Dense(32, activation="relu"),
      layers.Dense(140, activation="sigmoid")])

  def call(self, x):
    encoded = self.encoder(x)
    decoded = self.decoder(encoded)
    return decoded

autoencoder = AnomalyDetector()

# %%
# compile the model with optimizer Loss
autoencoder.compile(optimizer='adam', loss='mae')

# %%
history = autoencoder.fit(normal_train_data, normal_train_data, 
          epochs=20, 
          batch_size=512,
          validation_data=(test_data, test_data),
          shuffle=True)
# Out:
# Epoch 1/20
# 5/5 [==============================] - 2s 78ms/step - loss: 0.0581 - val_loss: 0.0527
# Epoch 2/20
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0548 - val_loss: 0.0502
# Epoch 3/20
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0508 - val_loss: 0.0480
# Epoch 4/20
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0460 - val_loss: 0.0460
# Epoch 5/20
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0414 - val_loss: 0.0434
# Epoch 6/20
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0373 - val_loss: 0.0417
# Epoch 7/20
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0336 - val_loss: 0.0397
# Epoch 8/20
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0304 - val_loss: 0.0384
# Epoch 9/20
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0281 - val_loss: 0.0373
# Epoch 10/20
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0265 - val_loss: 0.0365
# Epoch 11/20
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0252 - val_loss: 0.0357
# Epoch 12/20
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0243 - val_loss: 0.0354
# Epoch 13/20
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0237 - val_loss: 0.0347
# Epoch 14/20
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0231 - val_loss: 0.0345
# Epoch 15/20
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0226 - val_loss: 0.0340
# Epoch 16/20
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0221 - val_loss: 0.0336
# Epoch 17/20
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0216 - val_loss: 0.0336
# Epoch 18/20
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0212 - val_loss: 0.0333
# Epoch 19/20
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0208 - val_loss: 0.0333
# Epoch 20/20
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0205 - val_loss: 0.0332

# %%
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend()

# %%
# Decoder network convert back to original input
encoded_data = autoencoder.encoder(normal_test_data).numpy()
decoded_data = autoencoder.decoder(encoded_data).numpy()

plt.plot(normal_test_data[0], 'b')
plt.plot(decoded_data[0], 'r')
plt.fill_between(np.arange(140), decoded_data[0], normal_test_data[0], color='lightcoral')
plt.legend(labels=["Input", "Reconstruction", "Error"])
plt.show()

# %%
encoded_data = autoencoder.encoder(anomalous_test_data).numpy()
decoded_data = autoencoder.decoder(encoded_data).numpy()

plt.plot(anomalous_test_data[0], 'b')
plt.plot(decoded_data[0], 'r')
plt.fill_between(np.arange(140), decoded_data[0], anomalous_test_data[0], color='lightcoral')
plt.legend(labels=["Input", "Reconstruction", "Error"])
plt.show()

# %%
reconstructions = autoencoder.predict(normal_train_data)
train_loss = tf.keras.losses.mae(reconstructions, normal_train_data)

plt.hist(train_loss[None,:], bins=50)
plt.xlabel("Train loss")
plt.ylabel("No of examples")
plt.show()
# Out:
# 74/74 [==============================] - 0s 3ms/step

# %%
threshold = np.mean(train_loss) + np.std(train_loss)
print("Threshold: ", threshold)
# Out:
# Threshold:  0.03250496215302045

# %%
reconstructions = autoencoder.predict(anomalous_test_data)
test_loss = tf.keras.losses.mae(reconstructions, anomalous_test_data)

plt.hist(test_loss[None, :], bins=50)
plt.xlabel("Test loss")
plt.ylabel("No of examples")
plt.show()
# Out:
# 14/14 [==============================] - 0s 4ms/step

# %%
def predict(model, data, threshold):
  reconstructions = model(data)
  loss = tf.keras.losses.mae(reconstructions, data)
  return tf.math.less(loss, threshold)

def print_stats(predictions, labels):
  print("Accuracy = {}".format(accuracy_score(labels, predictions)))
  print("Precision = {}".format(precision_score(labels, predictions)))
  print("Recall = {}".format(recall_score(labels, predictions)))

# %%
preds = predict(autoencoder, test_data, threshold)
print_stats(preds, test_labels)
# Out:
# Accuracy = 0.945
# Precision = 0.9922027290448343
# Recall = 0.9089285714285714
